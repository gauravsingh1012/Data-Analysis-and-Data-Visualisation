# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/gauravsingh1012/Mining-Historical-Tweets-For-Data-Visualisation-and-Sentiment-Analysis/blob/master/Mining_Historical_Twitter_For_Data_Visualisation_and_Sentiment_Analysis.ipynb)

# %%
import os

os.chdir('/content')

# !rm -rf Mining-*
# !git clone https://github.com/gauravsingh1012/Mining-Historical-Tweets-For-Data-Visualisation-and-Sentiment-Analysis.git

os.chdir('/content/Mining-Historical-Tweets-For-Data-Visualisation-and-Sentiment-Analysis')
# !pwd
# Out:
# Cloning into 'Mining-Historical-Tweets-For-Data-Visualisation-and-Sentiment-Analysis'...
# remote: Counting objects: 41, done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 41 (delta 18), reused 19 (delta 4), pack-reused 0
# Unpacking objects: 100% (41/41), done.
# /content/Mining-Historical-Tweets-For-Data-Visualisation-and-Sentiment-Analysis

# %%
# !pip3 install twint
# Out:
# ...
#     100% |████████████████████████████████| 880kB 10.6MB/s
# ...
#     100% |████████████████████████████████| 204kB 16.0MB/s
# ...
#     100% |████████████████████████████████| 122kB 22.7MB/s
# ...
#     100% |████████████████████████████████| 286kB 18.8MB/s
# ...
#     100% |████████████████████████████████| 256kB 17.4MB/s
# ...
#     100% |████████████████████████████████| 481kB 16.7MB/s
# ...
#     100% |████████████████████████████████| 204kB 19.0MB/s
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/0f/be/5a/f24f1bcba7f75b8a751fb37e7beda82d507bba698479184aef
# done
#   Stored in directory: /content/.cache/pip/wheels/22/5c/b5/12e0dfdfa85bea67b23628b6425fae715c687e947a45ee3df9
# done
#   Stored in directory: /content/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built twint pysocks idna-ssl
# ...

# %%
import twint

# Configure
c = twint.Config()
c.Username = "EconomicTimes"
c.Search = "SBI"
#c.Format = "Tweet id: {id} | Tweet: {tweet}"

# %%
twint.run.Search(c)
# Out:
# 1027226682300788737 2018-08-08 16:15:00 UTC <EconomicTimes> #SBI launches #MOPAD, a unified payment terminal https://goo.gl/UXwHEX
# 1026075347249451010 2018-08-05 12:00:00 UTC <EconomicTimes> The highest collection is by State Bank of India (SBI) which raised Rs 2,433 crore, nearly half of the total fines  https://economictimes.indiatimes.com/industry/banking/finance/banking/bank-penalties-cost-depositors-rs-5000-crore-in-2017-18/articleshow/65276458.cms?utm_source=twitter.com&utm_medium=Social&utm_campaign=ETTWMain …
# 1025054498803404801 2018-08-02 16:23:31 UTC <EconomicTimes> #SBI ties up with #RelianceJio to accelerate digital transactions |  https://goo.gl/DVxkBh  pic.twitter.com/NoIXSXbfqP
# 1025028005373071365 2018-08-02 14:38:15 UTC <EconomicTimes> The release also said that #Jio Prime customers of #SBI will be offered additional loyalty reward earning opportunities.   https://goo.gl/Xe8x9M
# ...

# %%
c.Format = ""
# CSV Fieldnames
c.Custom = ["id", "user_id", "username", "tweet"]
c.Output = "twitter.csv"

# %%
twint.run.Search(c)

# %%
# !more twitter.csv
# Out:
# 955511208597184512 2018-01-22 18:43:19 UTC <now> pineapples are the best fruit
# 🍍🍍
